# %%
# File location and type
file_location = "/FileStore/tables/tips.csv"
file_type = "csv"

# read the file
df=spark.read.csv(file_location, header='True', inferSchema='True')
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----------+----+------+------+---+------+----+
# total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|
#      26.88|3.12|  Male|    No|Sun|Dinner|   4|
#      15.04|1.96|  Male|    No|Sun|Dinner|   2|
#      14.78|3.23|  Male|    No|Sun|Dinner|   2|
# ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>root
# -- total_bill: double (nullable = true)
# -- tip: double (nullable = true)
# -- sex: string (nullable = true)
# -- smoker: string (nullable = true)
# -- day: string (nullable = true)
# -- time: string (nullable = true)
# -- size: integer (nullable = true)
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']</div>

# %%
#handling the categorical features using ordinal encoding
from pyspark.ml.feature import StringIndexer

# %%
indexer=StringIndexer(inputCol='sex',outputCol='sex_indexed')
df_r=indexer.fit(df).transform(df)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----------+----+------+------+---+------+----+-----------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|
# +----------+----+------+------+---+------+----+-----------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|
# ...

# %%
indexer=StringIndexer(inputCols=['smoker', 'day', 'time'],outputCols=['smoker_indexed', 'day_indexed', 'time_indexed'])
df_r=indexer.fit(df_r).transform(df_r)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|
# ...

# %%
df_r.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['total_bill',
#  'tip',
#  'sex',
#  'smoker',
#  'day',
#  'time',
#  'size',
#  'sex_indexed',
#  'smoker_indexed',
#  'day_indexed',
#  'time_indexed']</div>

# %%
from pyspark.ml.feature import VectorAssembler
featureassembler=VectorAssembler(inputCols=['tip', 'size', 'sex_indexed', 'smoker_indexed', 'day_indexed', 'time_indexed'], outputCol='independent features')
result=featureassembler.transform(df_r)

# %%
result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_indexed|independent features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+------------+--------------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|         0.0|[1.01,2.0,1.0,0.0...|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|         0.0|[1.66,3.0,0.0,0.0...|
# ...

# %%
result.select('independent features').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------------+
# independent features|
# +--------------------+
# [1.01,2.0,1.0,0.0...|
# [1.66,3.0,0.0,0.0...|
# [3.5,3.0,0.0,0.0,...|
# [3.31,2.0,0.0,0.0...|
# [3.61,4.0,1.0,0.0...|
# [4.71,4.0,0.0,0.0...|
# [2.0,2.0,0.0,0.0,...|
# [3.12,4.0,0.0,0.0...|
# [1.96,2.0,0.0,0.0...|
# [3.23,2.0,0.0,0.0...|
# [1.71,2.0,0.0,0.0...|
# [5.0,4.0,1.0,0.0,...|
# [1.57,2.0,0.0,0.0...|
# [3.0,4.0,0.0,0.0,...|
# [3.02,2.0,1.0,0.0...|
# [3.92,2.0,0.0,0.0...|
# [1.67,3.0,1.0,0.0...|
# [3.71,3.0,0.0,0.0...|
# [3.5,3.0,1.0,0.0,...|
# (6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
final_data=result.select('independent features', 'total_bill')

# %%
final_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------------+----------+
# independent features|total_bill|
# +--------------------+----------+
# [1.01,2.0,1.0,0.0...|     16.99|
# [1.66,3.0,0.0,0.0...|     10.34|
# [3.5,3.0,0.0,0.0,...|     21.01|
# [3.31,2.0,0.0,0.0...|     23.68|
# [3.61,4.0,1.0,0.0...|     24.59|
# [4.71,4.0,0.0,0.0...|     25.29|
# [2.0,2.0,0.0,0.0,...|      8.77|
# [3.12,4.0,0.0,0.0...|     26.88|
# [1.96,2.0,0.0,0.0...|     15.04|
# [3.23,2.0,0.0,0.0...|     14.78|
# [1.71,2.0,0.0,0.0...|     10.27|
# [5.0,4.0,1.0,0.0,...|     35.26|
# [1.57,2.0,0.0,0.0...|     15.42|
# [3.0,4.0,0.0,0.0,...|     18.43|
# [3.02,2.0,1.0,0.0...|     14.83|
# ...

# %%
#implementing th LR model
from pyspark.ml.regression import LinearRegression

#train-test split
train_data, test_data=final_data.randomSplit([0.80, 0.20])
regressor=LinearRegression(featuresCol='independent features', labelCol='total_bill')
regressor=regressor.fit(train_data)

# %%
regressor.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>DenseVector([3.0746, 3.8385, -1.4732, 2.8397, -0.6546, -0.9718])</div>

# %%
regressor.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>1.3511570934114538</div>

# %%
pred_result=regressor.evaluate(test_data)

# %%
display_pred=pred_result.predictions

# %%
display_pred.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------------+----------+------------------+
# independent features|total_bill|        prediction|
# +--------------------+----------+------------------+
# (6,[0,1],[1.25,2.0])|     10.07|12.871403172922621|
# (6,[0,1],[1.25,2.0])|     10.51|12.871403172922621|
# (6,[0,1],[1.45,2.0])|      9.55| 13.48631318450899|
# (6,[0,1],[1.47,2.0])|     10.77|13.547804185667628|
# (6,[0,1],[2.24,3.0])|     16.04|19.753736983823334|
# (6,[0,1],[2.64,3.0])|     17.59| 20.98355700699607|
#  (6,[0,1],[3.0,2.0])|      14.0|18.251865774303347|
#  (6,[0,1],[3.0,4.0])|     20.45|25.928924281399713|
# ...

# %%
#performance metrics
pred_result.r2, pred_result.meanAbsoluteError,pred_result.meanSquaredError, pred_result.numInstances
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>(0.2764160517348925, 4.643332480085155, 34.38625879680219, 58)</div>
